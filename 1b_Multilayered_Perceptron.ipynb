# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
labels_list = [
    "buildings",
    "forest",
    "glacier",
    "mountain",
    "sea",
    "street"
]

labels_dict = {label:index for index, label in enumerate(labels_list)}

# %%
with open('/gdrive/My Drive/Kaggle/train.npy', 'rb') as f:
  X_train = np.load(f)
  X_train = X_train.astype("float32")

with open('/gdrive/My Drive/Kaggle/train labels.npy', 'rb') as f:
  y_train = np.load(f)
  y_train = y_train.astype("float32")
  # y_train = tf.reshape(y_train, (-1, 1))

print(f'Shape of X_train: {np.shape(X_train)}')
print(f'Shape of y_train: {np.shape(y_train)}')

with open('/gdrive/My Drive/Kaggle/test.npy', 'rb') as f:
  X_test = np.load(f)
  X_test = X_test.astype("float32")

with open('/gdrive/My Drive/Kaggle/test labels.npy', 'rb') as f:
  y_test = np.load(f)
  y_test = y_test.astype("float32")
  # y_test = tf.reshape(y_test, (-1, 1))


print(f'Shape of X_test : {np.shape(X_test)}')
print(f'Shape of y_test : {np.shape(y_test)}')
# Out:
# Shape of X_train: (14034, 7500)
# Shape of y_train: (14034,)
# Shape of X_test : (3000, 7500)
# Shape of y_test : (3000,)

# %%
# this is a template to have as a walkthrough

inputs = keras.Input(shape=(784,), name="digits")
x = layers.Dense(64, activation="relu", name="dense_1")(inputs)
x = layers.Dense(64, activation="relu", name="dense_2")(x)
outputs = layers.Dense(10, activation="softmax", name="predictions")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Preprocess the data (these are NumPy arrays)
x_train = x_train.reshape(60000, 784).astype("float32") / 255
x_test = x_test.reshape(10000, 784).astype("float32") / 255

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# Reserve 10,000 samples for validation
x_val = x_train[-10000:]
y_val = y_train[-10000:]
x_train = x_train[:-10000]
y_train = y_train[:-10000]

model.compile(
    optimizer=keras.optimizers.RMSprop(),  # Optimizer
    # Loss function to minimize
    loss=keras.losses.SparseCategoricalCrossentropy(),
    # List of metrics to monitor
    metrics=[keras.metrics.SparseCategoricalAccuracy()],
)

print("Fit model on training data")
history = model.fit(
    x_train,
    y_train,
    batch_size=64,
    epochs=2,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    validation_data=(x_val, y_val),
)
history.history
# Out:
# Fit model on training data
# Epoch 1/2
# 782/782 [==============================] - 4s 4ms/step - loss: 0.3458 - sparse_categorical_accuracy: 0.8998 - val_loss: 0.1909 - val_sparse_categorical_accuracy: 0.9471
# Epoch 2/2
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1554 - sparse_categorical_accuracy: 0.9534 - val_loss: 0.1275 - val_sparse_categorical_accuracy: 0.9646
# {'loss': [0.3457811772823334, 0.15535275638103485],
#  'sparse_categorical_accuracy': [0.8997799754142761, 0.9534000158309937],
#  'val_loss': [0.1909097582101822, 0.12752945721149445],
#  'val_sparse_categorical_accuracy': [0.9470999836921692, 0.9646000266075134]}

# %%
import tensorflow as tf
import keras
from keras import layers

model_3_hidden = tf.keras.models.Sequential(name="MLP_3_hidden")
model_3_hidden.add(tf.keras.Input(shape=(7500,)))
model_3_hidden.add(tf.keras.layers.Dense(units=3750, activation='relu',    name="hidden_dense_1", kernel_initializer='random_normal', bias_initializer='zeros'))
# model_3_hidden.add(tf.keras.layers.Dense(units=1875, activation='relu',    name="hidden_dense_2", kernel_initializer='random_normal', bias_initializer='zeros'))
# model_3_hidden.add(tf.keras.layers.Dense(units=512,  activation='relu',    name="hidden_dense_3", kernel_initializer='random_normal', bias_initializer='zeros'))
model_3_hidden.add(tf.keras.layers.Dense(units=256,  activation='relu',    name="hidden_dense_4", kernel_initializer='random_normal', bias_initializer='zeros'))
# model_3_hidden.add(tf.keras.layers.Dense(units=128,  activation='relu',    name="hidden_dense_5", kernel_initializer='random_normal', bias_initializer='zeros'))
model_3_hidden.add(tf.keras.layers.Dense(units=32,   activation='relu',    name="hidden_dense_7", kernel_initializer='random_normal', bias_initializer='zeros'))
model_3_hidden.add(tf.keras.layers.Dense(units=6,    activation='softmax', name="output"))
print(model_3_hidden.summary())
print()

model_3_hidden.compile(
    # optimizer= keras.optimizers.RMSprop(),
    optimizer= 'adam',
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

history_3_hidden = model_3_hidden.fit(
    X_train,
    y_train,
    batch_size=128,
    epochs=10,
    verbose='auto',
    validation_data=(X_test, y_test)
)
# Out:
# Model: "MLP_3_hidden"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_dense_1 (Dense)      (None, 3750)              28128750
#
#  hidden_dense_4 (Dense)      (None, 256)               960256
#
#  hidden_dense_7 (Dense)      (None, 32)                8224
#
#  output (Dense)              (None, 6)                 198
#
# ...
# Total params: 29097428 (111.00 MB)
# Trainable params: 29097428 (111.00 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#
# Epoch 1/10
# 110/110 [==============================] - 79s 711ms/step - loss: 2.8191 - accuracy: 0.3536 - val_loss: 1.4379 - val_accuracy: 0.4493
# Epoch 2/10
# 110/110 [==============================] - 78s 711ms/step - loss: 1.4214 - accuracy: 0.4580 - val_loss: 1.3594 - val_accuracy: 0.4890
# Epoch 3/10
# ...

# %%
import tensorflow as tf
import keras
from keras import layers

model_6_hidden = tf.keras.models.Sequential(name="MLP_6_hidden")
model_6_hidden.add(tf.keras.Input(shape=(7500,)))
model_6_hidden.add(tf.keras.layers.Dense(units=3750, activation='relu',    name="hidden_dense_1", kernel_initializer='random_normal', bias_initializer='zeros'))
model_6_hidden.add(tf.keras.layers.Dense(units=1875, activation='relu',    name="hidden_dense_2", kernel_initializer='random_normal', bias_initializer='zeros'))
model_6_hidden.add(tf.keras.layers.Dense(units=512,  activation='relu',    name="hidden_dense_3", kernel_initializer='random_normal', bias_initializer='zeros'))
model_6_hidden.add(tf.keras.layers.Dense(units=256,  activation='relu',    name="hidden_dense_4", kernel_initializer='random_normal', bias_initializer='zeros'))
model_6_hidden.add(tf.keras.layers.Dense(units=128,  activation='relu',    name="hidden_dense_5", kernel_initializer='random_normal', bias_initializer='zeros'))
model_6_hidden.add(tf.keras.layers.Dense(units=32,   activation='relu',    name="hidden_dense_7", kernel_initializer='random_normal', bias_initializer='zeros'))
model_6_hidden.add(tf.keras.layers.Dense(units=6,    activation='softmax', name="output"))
print(model_6_hidden.summary())
print()

model_6_hidden.compile(
    # optimizer= keras.optimizers.RMSprop(),
    optimizer= 'adam',
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

history_6_hidden = model_6_hidden.fit(
    X_train,
    y_train,
    batch_size=128,
    epochs=10,
    verbose='auto',
    validation_data=(X_test, y_test)
)
# Out:
# Model: "MLP_6_hidden"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_dense_1 (Dense)      (None, 3750)              28128750
#
#  hidden_dense_2 (Dense)      (None, 1875)              7033125
#
#  hidden_dense_3 (Dense)      (None, 512)               960512
#
#  hidden_dense_4 (Dense)      (None, 256)               131328
#
#  hidden_dense_5 (Dense)      (None, 128)               32896
#
#  hidden_dense_7 (Dense)      (None, 32)                4128
#
#  output (Dense)              (None, 6)                 198
#
# ...
# Total params: 36290937 (138.44 MB)
# Trainable params: 36290937 (138.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
#
# Epoch 1/10
# 110/110 [==============================] - 107s 960ms/step - loss: 2.4123 - accuracy: 0.1687 - val_loss: 1.7917 - val_accuracy: 0.1670
# Epoch 2/10
# ...

# %%
# GRID SEARCH
import pickle
import tensorflow as tf
import keras
from keras import layers


number_of_hidden_layers = [3, 7, 10]
hidden_layer_units = [3750, 1875, 935, 512, 256, 128, 64, 32, 16, 8]
optimizers = ['sgd', 'adam']
losses = [keras.losses.SparseCategoricalCrossentropy()]
activation_functions = ['sigmoid', 'relu']
batch_sizes = [32, 64, 128, 256]

restart_flag = 0

for hidden_layers in number_of_hidden_layers:
  for optimizer in optimizers:
    for loss in losses:
      for batch_size in batch_sizes:
        for activation_function in activation_functions:

          model_name = f"Model_{str(hidden_layers)}_{str(optimizer)}_SCCE_{activation_function}_{batch_size}"
          file_name = f'/gdrive/My Drive/Kaggle/NN Models Reports/{model_name}.txt'

          if model_name == "Model_10_adam_SCCE_relu_32":
            restart_flag = 1

          if restart_flag:
            print()
            print(f'Started Training model: {model_name}')
            model = tf.keras.models.Sequential(name=model_name)
            model.add(tf.keras.Input(shape=(7500,)))

            for hidden_layer in range(hidden_layers):
              model.add(tf.keras.layers.Dense(
                  units=hidden_layer_units[hidden_layer],
                  activation=activation_function,
                  name=f"hidden_layer_{hidden_layer}",
                  kernel_initializer='glorot_uniform',
                  bias_initializer='zeros'
              ))
            model.add(tf.keras.layers.Dense(units=6, activation='softmax', name="output"))
            # print(model.summary())
            # with open(file_name, 'a') as writefile:
            #   writefile.write(str(model.summary()) + "\n\n")


            model.compile(
              optimizer= optimizer,
              loss=loss,
              metrics=['accuracy']
            )
            print('Model successfully compiled. Starting training...')

            history = model.fit(
              X_train,
              y_train,
              batch_size=batch_size,
              epochs=10,
              verbose='auto',
              validation_data=(X_test, y_test)
            )
            print()
            print('Starting writing history to file...')
            writefile = open('/gdrive/My Drive/Kaggle/NN Models Reports/' + model_name + "_history.pkl", "wb")
            pickle.dump(history, writefile)
            writefile.close()
            print('Finished writing history to file ...')
            print()
# Out:
# Started Training model: Model_10_adam_SCCE_relu_32
# Model successfully compiled. Starting trining...
# Epoch 1/10
# 439/439 [==============================] - 312s 707ms/step - loss: 1.6741 - accuracy: 0.2755 - val_loss: 1.5411 - val_accuracy: 0.3617
# Epoch 2/10
# 439/439 [==============================] - 325s 739ms/step - loss: 1.4811 - accuracy: 0.3827 - val_loss: 1.4159 - val_accuracy: 0.4107
# Epoch 3/10
# 439/439 [==============================] - 313s 713ms/step - loss: 1.4042 - accuracy: 0.4073 - val_loss: 1.4229 - val_accuracy: 0.4053
# Epoch 4/10
# 439/439 [==============================] - 321s 731ms/step - loss: 1.3737 - accuracy: 0.4298 - val_loss: 1.3733 - val_accuracy: 0.4377
# Epoch 5/10
# 439/439 [==============================] - 313s 713ms/step - loss: 1.3358 - accuracy: 0.4506 - val_loss: 1.3593 - val_accuracy: 0.4320
# Epoch 6/10
# ...

# %%
import pickle
import tensorflow as tf
import keras
from keras import layers

number_of_hidden_layers = [3, 7, 10]
hidden_layer_units = [3750, 1875, 935, 512, 256, 128, 64, 32, 16, 8]
optimizers = ['sgd', 'adam']
losses = [keras.losses.SparseCategoricalCrossentropy()]
activation_functions = ['sigmoid', 'relu']
batch_sizes = [32, 64, 128, 256]

hidden_layers = 3
optimizer = 'sgd'
loss = keras.losses.SparseCategoricalCrossentropy()
batch_size = 32
activation_function = 'relu'
epochs = 40

model_name = f"FinalModel_{str(hidden_layers)}_{str(optimizer)}_SCCE_{activation_function}_{batch_size}"

print()
print(f'Started Training model: {model_name}')
model = tf.keras.models.Sequential(name=model_name)
model.add(tf.keras.Input(shape=(7500,)))

for hidden_layer in range(hidden_layers):
  model.add(tf.keras.layers.Dense(
      units=hidden_layer_units[hidden_layer],
      activation=activation_function,
      name=f"hidden_layer_{hidden_layer}",
      kernel_initializer='glorot_uniform',
      bias_initializer='zeros'
  ))
model.add(tf.keras.layers.Dense(units=6, activation='softmax', name="output"))
print()
print(model.summary())
# with open(file_name, 'a') as writefile:
#   writefile.write(str(model.summary()) + "\n\n")


model.compile(
  optimizer= optimizer,
  loss=loss,
  metrics=['accuracy']
)
print('Model successfully compiled. Starting training...')

history = model.fit(
  X_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  verbose='auto',
  validation_data=(X_test, y_test)
)
print()
print('Starting writing history to file...')
writefile = open('/gdrive/My Drive/Kaggle/NN Models Reports/' + model_name + "_history.pkl", "wb")
pickle.dump(history, writefile)
writefile.close()
print('Finished writing history to file ...')
print()
# Out:
# Started Training model: FinalModel_3_sgd_SCCE_relu_32
#
# Model: "FinalModel_3_sgd_SCCE_relu_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer_0 (Dense)      (None, 3750)              28128750
#
#  hidden_layer_1 (Dense)      (None, 1875)              7033125
#
#  hidden_layer_2 (Dense)      (None, 935)               1754060
#
#  output (Dense)              (None, 6)                 5616
#
# ...
# Total params: 36921551 (140.84 MB)
# Trainable params: 36921551 (140.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model successfully compiled. Starting training...
# Epoch 1/40
# 439/439 [==============================] - 163s 370ms/step - loss: 1.3446 - accuracy: 0.4769 - val_loss: 1.2155 - val_accuracy: 0.5427
# Epoch 2/40
# ...

# %%
import pickle
import tensorflow as tf
import keras
from keras import layers

number_of_hidden_layers = [3, 7, 10]
hidden_layer_units = [3750, 1875, 935, 512, 256, 128, 64, 32, 16, 8]
optimizers = ['sgd', 'adam']
losses = [keras.losses.SparseCategoricalCrossentropy()]
activation_functions = ['sigmoid', 'relu']
batch_sizes = [32, 64, 128, 256]

hidden_layers = 7
optimizer = 'sgd'
loss = keras.losses.SparseCategoricalCrossentropy()
batch_size = 32
activation_function = 'relu'
epochs = 40

model_name = f"FinalModel_{str(hidden_layers)}_{str(optimizer)}_SCCE_{activation_function}_{batch_size}"

print()
print(f'Started Training model: {model_name}')
model = tf.keras.models.Sequential(name=model_name)
model.add(tf.keras.Input(shape=(7500,)))

for hidden_layer in range(hidden_layers):
  model.add(tf.keras.layers.Dense(
      units=hidden_layer_units[hidden_layer],
      activation=activation_function,
      name=f"hidden_layer_{hidden_layer}",
      kernel_initializer='glorot_uniform',
      bias_initializer='zeros'
  ))
model.add(tf.keras.layers.Dense(units=6, activation='softmax', name="output"))
print()
print(model.summary())
# with open(file_name, 'a') as writefile:
#   writefile.write(str(model.summary()) + "\n\n")


model.compile(
  optimizer= optimizer,
  loss=loss,
  metrics=['accuracy']
)
print('Model successfully compiled. Starting training...')

history = model.fit(
  X_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  verbose='auto',
  validation_data=(X_test, y_test)
)
print()
print('Starting writing history to file...')
writefile = open('/gdrive/My Drive/Kaggle/NN Models Reports/' + model_name + "_history.pkl", "wb")
pickle.dump(history, writefile)
writefile.close()
print('Finished writing history to file ...')
print()
# Out:
# Started Training model: FinalModel_7_sgd_SCCE_relu_32
#
# Model: "FinalModel_7_sgd_SCCE_relu_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer_0 (Dense)      (None, 3750)              28128750
#
#  hidden_layer_1 (Dense)      (None, 1875)              7033125
#
#  hidden_layer_2 (Dense)      (None, 935)               1754060
#
#  hidden_layer_3 (Dense)      (None, 512)               479232
#
#  hidden_layer_4 (Dense)      (None, 256)               131328
#
#  hidden_layer_5 (Dense)      (None, 128)               32896
#
#  hidden_layer_6 (Dense)      (None, 64)                8256
#
#  output (Dense)              (None, 6)                 390
#
# ...
# Total params: 37568037 (143.31 MB)
# Trainable params: 37568037 (143.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# ...

# %%
import pickle
import tensorflow as tf
import keras
from keras import layers

number_of_hidden_layers = [3, 7, 10]
hidden_layer_units = [3750, 1875, 935, 512, 256, 128, 64, 32, 16, 8]
optimizers = ['sgd', 'adam']
losses = [keras.losses.SparseCategoricalCrossentropy()]
activation_functions = ['sigmoid', 'relu']
batch_sizes = [32, 64, 128, 256]

hidden_layers = 7
optimizer = 'adam'
loss = keras.losses.SparseCategoricalCrossentropy()
batch_size = 64
activation_function = 'relu'
epochs = 40

model_name = f"FinalModel_{str(hidden_layers)}_{str(optimizer)}_SCCE_{activation_function}_{batch_size}"

print()
print(f'Started Training model: {model_name}')
model = tf.keras.models.Sequential(name=model_name)
model.add(tf.keras.Input(shape=(7500,)))

for hidden_layer in range(hidden_layers):
  model.add(tf.keras.layers.Dense(
      units=hidden_layer_units[hidden_layer],
      activation=activation_function,
      name=f"hidden_layer_{hidden_layer}",
      kernel_initializer='glorot_uniform',
      bias_initializer='zeros'
  ))
model.add(tf.keras.layers.Dense(units=6, activation='softmax', name="output"))
print()
print(model.summary())
# with open(file_name, 'a') as writefile:
#   writefile.write(str(model.summary()) + "\n\n")


model.compile(
  optimizer= optimizer,
  loss=loss,
  metrics=['accuracy']
)
print('Model successfully compiled. Starting training...')

history = model.fit(
  X_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  verbose='auto',
  validation_data=(X_test, y_test)
)
print()
print('Starting writing history to file...')
writefile = open('/gdrive/My Drive/Kaggle/NN Models Reports/' + model_name + "_history.pkl", "wb")
pickle.dump(history, writefile)
writefile.close()
print('Finished writing history to file ...')
print()
# Out:
# Started Training model: FinalModel_7_adam_SCCE_relu_64
#
# Model: "FinalModel_7_adam_SCCE_relu_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer_0 (Dense)      (None, 3750)              28128750
#
#  hidden_layer_1 (Dense)      (None, 1875)              7033125
#
#  hidden_layer_2 (Dense)      (None, 935)               1754060
#
#  hidden_layer_3 (Dense)      (None, 512)               479232
#
#  hidden_layer_4 (Dense)      (None, 256)               131328
#
#  hidden_layer_5 (Dense)      (None, 128)               32896
#
#  hidden_layer_6 (Dense)      (None, 64)                8256
#
#  output (Dense)              (None, 6)                 390
#
# ...
# Total params: 37568037 (143.31 MB)
# Trainable params: 37568037 (143.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# ...

# %%
import pickle
import tensorflow as tf
import keras
from keras import layers

number_of_hidden_layers = [3, 7, 10]
hidden_layer_units = [3750, 1875, 935, 512, 256, 128, 64, 32, 16, 8]
optimizers = ['sgd', 'adam']
losses = [keras.losses.SparseCategoricalCrossentropy()]
activation_functions = ['sigmoid', 'relu']
batch_sizes = [32, 64, 128, 256]

hidden_layers = 3
optimizer = tf.keras.optimizers.SGD(learning_rate=0.03)
loss = keras.losses.SparseCategoricalCrossentropy()
batch_size = 32
activation_function = 'relu'
epochs = 40

model_name = f"FinalModel_{str(hidden_layers)}_sgd0.03_SCCE_{activation_function}_{batch_size}"

print()
print(f'Started Training model: {model_name}')
model = tf.keras.models.Sequential(name=model_name)
model.add(tf.keras.Input(shape=(7500,)))

for hidden_layer in range(hidden_layers):
  model.add(tf.keras.layers.Dense(
      units=hidden_layer_units[hidden_layer],
      activation=activation_function,
      name=f"hidden_layer_{hidden_layer}",
      kernel_initializer='glorot_uniform',
      bias_initializer='zeros'
  ))
model.add(tf.keras.layers.Dense(units=6, activation='softmax', name="output"))
print()
print(model.summary())
# with open(file_name, 'a') as writefile:
#   writefile.write(str(model.summary()) + "\n\n")


model.compile(
  optimizer= optimizer,
  loss=loss,
  metrics=['accuracy']
)
print('Model successfully compiled. Starting training...')

history = model.fit(
  X_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  verbose='auto',
  validation_data=(X_test, y_test)
)
print()
print('Starting writing history to file...')
writefile = open('/gdrive/My Drive/Kaggle/NN Models Reports/' + model_name + "_history.pkl", "wb")
pickle.dump(history, writefile)
writefile.close()
print('Finished writing history to file ...')
print()
# Out:
# Started Training model: FinalModel_3_sgd0.03_SCCE_relu_32
#
# Model: "FinalModel_3_sgd0.03_SCCE_relu_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer_0 (Dense)      (None, 3750)              28128750
#
#  hidden_layer_1 (Dense)      (None, 1875)              7033125
#
#  hidden_layer_2 (Dense)      (None, 935)               1754060
#
#  output (Dense)              (None, 6)                 5616
#
# ...
# Total params: 36921551 (140.84 MB)
# Trainable params: 36921551 (140.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model successfully compiled. Starting training...
# Epoch 1/40
# 439/439 [==============================] - 152s 344ms/step - loss: 1.3766 - accuracy: 0.4602 - val_loss: 1.4497 - val_accuracy: 0.4513
# Epoch 2/40
# ...

# %%
import pickle
import tensorflow as tf
import keras
from keras import layers

number_of_hidden_layers = [3, 7, 10]
hidden_layer_units = [3750, 1875, 935, 512, 256, 128, 64, 32, 16, 8]
optimizers = ['sgd', 'adam']
losses = [keras.losses.SparseCategoricalCrossentropy()]
activation_functions = ['sigmoid', 'relu']
batch_sizes = [32, 64, 128, 256]

hidden_layers = 3
optimizer = tf.keras.optimizers.SGD(learning_rate=0.03, momentum=0.9)
loss = keras.losses.SparseCategoricalCrossentropy()
batch_size = 32
activation_function = 'relu'
epochs = 40

model_name = f"FinalModel_{str(hidden_layers)}_sgd0.03_SCCE_{activation_function}_{batch_size}"

print()
print(f'Started Training model: {model_name}')
model = tf.keras.models.Sequential(name=model_name)
model.add(tf.keras.Input(shape=(7500,)))

for hidden_layer in range(hidden_layers):
  model.add(tf.keras.layers.Dense(
      units=hidden_layer_units[hidden_layer],
      activation=activation_function,
      name=f"hidden_layer_{hidden_layer}",
      kernel_initializer='glorot_uniform',
      bias_initializer='zeros'
  ))
model.add(tf.keras.layers.Dense(units=6, activation='softmax', name="output"))
print()
print(model.summary())
# with open(file_name, 'a') as writefile:
#   writefile.write(str(model.summary()) + "\n\n")


model.compile(
  optimizer= optimizer,
  loss=loss,
  metrics=['accuracy']
)
print('Model successfully compiled. Starting training...')

history = model.fit(
  X_train,
  y_train,
  batch_size=batch_size,
  epochs=epochs,
  verbose='auto',
  validation_data=(X_test, y_test)
)
print()
print('Starting writing history to file...')
writefile = open('/gdrive/My Drive/Kaggle/NN Models Reports/' + model_name + "_history.pkl", "wb")
pickle.dump(history, writefile)
writefile.close()
print('Finished writing history to file ...')
print()
# Out:
# Started Training model: FinalModel_3_sgd0.03_SCCE_relu_32
#
# Model: "FinalModel_3_sgd0.03_SCCE_relu_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_layer_0 (Dense)      (None, 3750)              28128750
#
#  hidden_layer_1 (Dense)      (None, 1875)              7033125
#
#  hidden_layer_2 (Dense)      (None, 935)               1754060
#
#  output (Dense)              (None, 6)                 5616
#
# ...
# Total params: 36921551 (140.84 MB)
# Trainable params: 36921551 (140.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Model successfully compiled. Starting training...
# Epoch 1/40
# 439/439 [==============================] - 202s 460ms/step - loss: 1.5715 - accuracy: 0.3940 - val_loss: 1.5165 - val_accuracy: 0.4123
# Epoch 2/40
# ...
